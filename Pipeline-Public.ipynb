# %%
'''
FermiPy Pipeline
==============================================
Created by Tai Withers, 08/2021
Modified by Tai Withers on 31/08/2021
==============================================

'''

# %%
# general
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, date, timedelta, time
from dateutil.relativedelta import relativedelta
import os

# email handling
import imaplib
import email
from email.header import decode_header
import webbrowser
import smtplib
from email import encoders
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
# https://www.thepythoncode.com/article/reading-emails-in-python
# https://www.thepythoncode.com/article/sending-emails-in-python-smtplib

# accessing gcn archives
from requests_html import HTMLSession
import requests

# using catalog
import xml.etree.ElementTree as ET

# making config files
import yaml

# accessing database
import mariadb
import sys
# https://mariadb.com/resources/blog/how-to-connect-python-programs-to-mariadb/

# fermi analysis
# from fermipy.gtanalysis import GTAnalysis
# some weird stuff with matplotlib versions
# roiplotter
# https://github.com/FermiSummerSchool/fermi-summer-school/tree/master/Likelihood_Advanced

# %% [markdown]
# # Send GCN Archives to Email

# %%
def get_archives(print_archives=False):
    '''
    Accesses the GCN Archives pages and returns a list of all of the links to individual notices
    '''
    session = HTMLSession()
    notices = ['https://gcn.gsfc.nasa.gov/notices_amon_icecube_cascade/135196_31863828.amon','https://gcn.gsfc.nasa.gov/notices_amon_icecube_cascade/135136_69399950.amon','https://gcn.gsfc.nasa.gov/notices_amon_icecube_cascade/134912_80902176.amon']
    # cascade contains test events so I added the real ones manually

    link_list= ['https://gcn.gsfc.nasa.gov/amon_hese_events.html',
                'https://gcn.gsfc.nasa.gov/amon_ehe_events.html',
                'https://gcn.gsfc.nasa.gov/amon_icecube_gold_bronze_events.html',
                'https://gcn.gsfc.nasa.gov/amon_nu_em_coinc_events.html']

    for link in link_list:
        link_session = session.get(link)
        for i in link_session.html.absolute_links:
            if '.amon' in i: notices.append(i)
    
    if print_archives: 
        for i in notices: print(i)
            
    return notices

def mail_gcn(notices, print_confirmation=False):
    '''
    Takes a list of links and emails the contents of each link to ******@gmail.com 
    '''
    
    email = "******@gmail.com"
    password = "******"
    subject = "GCN Archives"
    
    num_sent = 0

    def create_mail(FROM, TO, subject, body):
        msg = MIMEMultipart("alternative")# initialize the message 
        # set the sender, reciever, subject, body
        msg["From"] = FROM
        msg["To"] = TO
        msg["Subject"] = subject
        msg.attach(MIMEText(body,"plain"))
        return msg

    def send_mail(email, password, FROM, TO, msg):
        server = smtplib.SMTP("smtp.gmail.com", 587) # initialize the SMTP server
        server.starttls() # connect to the SMTP server as TLS mode (secure) and send EHLO        
        server.login(email, password)# login to the account using the credentials        
        server.sendmail(FROM, TO, msg.as_string())# send the email        
        server.quit()# terminate the SMTP session
    
    for i in notices:
        text = requests.get(i).text
        body = [] # list to handle single or updated notices
        
        if text.count('TITLE')>1: # deal with notice updates
            def find_nth(haystack, needle, n):
                start = haystack.find(needle)
                while start >= 0 and n > 1:
                    start = haystack.find(needle, start+len(needle))
                    n -= 1
                return start
            second_title_index = find_nth(text,'TITLE',2)
            body.append(text[:second_title_index]) # first notice
            body.append(text[second_title_index:]) # update
        else:
            body.append(text) # singular notice
        
        for f in body: # send the email
            msg = create_mail(email, email, subject, f)
            send_mail(email, password, email, email, msg)
        
        if print_confirmation: print(i,len(body), "Sent")
        num_sent+= len(body)
        
    if print_confirmation: print('Done', num_sent)

# %%
# notices = get_archives()
# notices_1 = notices[:50]
# notices_2 = notices[50:]

# if you don't split it up like this the gmail server gets mad and kicks you out
# total: 146 emails

# %%
# mail_gcn(notices_1,print_confirmation=True)

# %%
# mail_gcn(notices_2,print_confirmation=True)

# %% [markdown]
# # Email Parsing

# %%
def get_gmail (username, password, num_messages=0, print_inbox=False, subject_filter="", sender_filter=""):   
    '''
    Takes email credentials and subject/sender filters
    Returns list of all emails in the inbox
    Each list element is formatted [subject, sender, message]
    '''
    
    imap = imaplib.IMAP4_SSL("imap.gmail.com") # create an IMAP4 class with SSL 
    imap.login(username, password) # authenticate
    
    status, messages = imap.select("INBOX")
    messages = int(messages[0]) # total number of emails
    
    if num_messages==0: num_messages=messages

    inbox = [] # [subject, from, message]

    for i in range(messages, messages-num_messages, -1):
        res, msg = imap.fetch(str(i), "(RFC822)") # fetch the email message by ID
        this_message = {}

        for response in msg:
            if isinstance(response, tuple):
                msg = email.message_from_bytes(response[1]) # parse a bytes email into a message object

                # decode the email subject    
                subject, encoding = decode_header(msg["Subject"])[0] 
                if isinstance(subject, bytes): subject = subject.decode(encoding)

                # decode email sender
                From, encoding = decode_header(msg.get("From"))[0]
                
                if isinstance(From, bytes): From = From.decode(encoding)
                if From=='******@gmail.com': # from has multiple formats, we want email only
                    sender=From
                else:
                    sender = From[From.index('<')+1:From.index('>')] # just email address
                
                    
                # EMAIL FILTERING 
                subject_match = subject_filter=="" or subject==subject_filter
                sender_match = sender_filter=="" or sender==sender_filter
                    
                if subject_match and sender_match:
                    if print_inbox: print("Subject:", subject, "\nFrom:", From)
                    this_message['Subject'] = subject
                    this_message['Sent From'] = sender

                    for part in msg.walk(): # iterate over email parts
                        # extract content type of email
                        content_type = part.get_content_type()
                        content_disposition = str(part.get("Content-Disposition"))
                        try: body = part.get_payload(decode=True).decode() # get the email body
                        except: pass

                        # print text/plain emails and skip attachments
                        if content_type == "text/plain" and "attachment" not in content_disposition:
                            if print_inbox: print(body)
                            this_message['Message'] = body

                    if print_inbox: print("="*100)
                        
        if this_message: inbox.append(this_message) # only append if not empty
    
    # close the connection and logout
    imap.close()
    imap.logout()
        
    return inbox

def numerical_month(str_mon):
    '''
    Turn a month abbreviation into a numerical index
    '''
    return ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'].index(str_mon) + 1

def general_scraper (msg, print_alert=False):
    '''
    Pull relevant alert information from a string and return it in a dictionary
    '''
    
    # some pieces rely on the list order of values
    notice_type = 'NOTICE_TYPE'
    ra, dec = 'SRC_RA', 'SRC_DEC'
    date, time = 'DISCOVERY_DATE', 'DISCOVERY_TIME',
    energy = 'ENERGY'
    
    alert = {}
    
    # get notice date and time
    dt_string = msg[msg.index('NOTICE_DATE')+18+4:msg.index('NOTICE_DATE')+18+22]
    day = int(dt_string[:2])
    month = int(numerical_month(dt_string[3:6]))
    year = int('20'+dt_string[7:9])
    hour = int(dt_string[10:12])
    minute = int(dt_string[13:15])
    second = int(dt_string[16:18])
    alert['Notice Date'] = datetime(year,month,day,hour=hour,minute=minute,second=second)
  
    # get event number and run number
    run_string = msg[msg.index("RUN_NUM")+18:]
    alert['Run'] = str(run_string[:run_string.index('\r')])
    event_string = msg[msg.index("EVENT_NUM")+18:]
    alert['Event'] = str(event_string[:event_string.index('\r')]) 
    
    # determine notice type
    n = msg.index(notice_type)
    alert['Type'] = msg[n+18 : n + msg[n:].index('\n')-1]
    
    # get RA
    ra_string = msg[msg.index(ra)+18:msg.index(dec)-2] # relies on dec
    J2000_splitter = ra_string.index("(J2000)")
    current_splitter = ra_string.index("(current)")
    s = ra_string[:J2000_splitter-1]
    alert['RA_J2000'] = float(s[:s.index('d')])
    s = ra_string[:current_splitter-1]
    alert['RA_current'] = float(ra_string[J2000_splitter+28:current_splitter-1][:s.index('d')])
    alert['RA_1950'] = float(ra_string[current_splitter+30:-7][:s.index('d')])
    
    # get DEC
    dec_string = msg[msg.index(dec)+18:msg.index('SRC_ERROR')-2] # relies on error
    J2000_splitter = dec_string.index("(J2000)")
    current_splitter = dec_string.index("(current)")
    s = dec_string[:J2000_splitter-1]
    alert['DEC_J2000'] = float(s[:s.index('d')])
    s = dec_string[:current_splitter-1]
    alert['DEC_current'] = float(dec_string[J2000_splitter+28:current_splitter-1][:s.index('d')])
    alert['DEC_1950'] = float(dec_string[current_splitter+30:-7][:s.index('d')])
    
    # get date
    alert['Event Date'] = msg[msg.index("DOY;")+7:msg.index("(yy/mm/dd)")-1]
    
    # get time
    alert['Event Time'] = msg[msg.index('SOD')+5:msg.index("} UT")]
    
    # error
    err_string = msg[msg.index('SRC_ERROR')+18:msg.index("50% containment")+16]
    n = err_string.index('[')
    if '90%' in err_string: # if lists both errors
        # 90%
        e90_string = err_string[:n] + err_string[n+1:err_string.index('radius')-1]
        if 'arcmin' in e90_string:
            alert['Error 90%'] = arcmin_to_deg(float(e90_string[:e90_string.index('arcmin')-1]))
        elif 'deg' in e90_string:
            alert['Error 90%'] = float(e90_string[:e90_string.index('deg')-1]) 
        # 50%
        err_string = msg[msg.index('SRC_ERROR50')+18:msg.index("50% containment")+16]
        n = err_string.index('[')
        e50_string = err_string[:n] + err_string[n+1:err_string.index('radius')-1]
        if 'arcmin' in e50_string:
            alert['Error 50%'] = arcmin_to_deg(float(e50_string[:e50_string.index('arcmin')-1]))
        elif 'deg' in e50_string:
            alert['Error 50%'] = float(e50_string[:e50_string.index('deg')-1])
    else: # only lists 50%
        if 'arcmin' in err_string:
            alert['Error 50%'] = arcmin_to_deg(float(err_string[:err_string.index('arcmin')-1]))
        elif 'deg' in err_string:
            alert['Error 50%'] = float(err_string[:err_string.index('deg')-1])
        alert['Error 90%'] = 0 # none would be more correct but this will allow database to be floats
        
      
    # Not every alert lists energy (HESE and NuEM consistently, encountered EHE w/o energy)
    try:
        energy_string = msg[msg.index(energy)+18:msg.index('eV]')+3]
        if 'MeV' in energy_string:
            alert['Energy'] = float(energy_string[:energy_string.index('MeV')-1])*10e6
        elif 'GeV' in energy_string:
            alert['Energy'] = float(energy_string[:energy_string.index('GeV')-1])*10e9
        elif 'TeV' in energy_string:
            alert['Energy'] = float(energy_string[:energy_string.index('TeV')-1])*10e12
    except ValueError:
        alert['Energy'] = 0 # none would be more correct but this will allow database to be floats
        
    # NuEM lists time
    if 'Neutrino-EM' in alert['Type']:
        alert['Time'] = float(msg[msg.index('DELTA_T')+18:msg.index('[sec]')])
    else: 
        alert['Time'] = 0 # none would be more correct but this will allow database to be floats
        
    # NuEM, Gold, and Bronze list false alarm rate
    if len(set(alert['Type']) & {'Neutrino-M', 'Gold', 'Bronze'}) > 0:
        alert['False Alarm Rate']: float(msg[msg.index('FAR')+18:msg.index('[yr^-1]')]) 
    else: alert['False Alarm Rate'] = 0 # none would be more correct but this will allow database to be floats
        
    # Gold and Bronze list signalness
    if 'Gold' in alert['Type'] or 'Bronze' in alert['Type']:
        alert['Signalness'] = float(msg[msg.index('SIGNALNESS')+18:msg.index('[dn]')])
    else: alert['Signalness'] = 0 # none would be more correct but this will allow database to be floats
    
    # printing
    if print_alert:
        for i in alert.keys():
            print(i+":\t"+alert[i])

    return alert

def get_catalog(xml):
    '''
    Takes an xml fermi catalog and returns a list of dictionaries
    Each source dictionary contains the name, RA/DEC, and flux
    '''
    sources = []
    
    root = ET.parse(xml).getroot() # access xml tree
    for child in root: # for element in catalog
        source = {}
        if child.attrib['type']=='PointSource': # point sources only
            source['Name'] = child.attrib['name'] 
            source['RA'] = float(child[1][0].attrib['value'])
            source['DEC'] = float(child[1][1].attrib['value'])
            source['Flux'] = float(child.attrib['Energy_Flux100'])
        if source: sources.append(source) # append only if not empty

    return sources

def find_nearby_sources(source_list, ra, dec, radius):
    '''
    Given a list of sources, and point in the sky, finds all sources within a given radius
    And returns them in  a list
    '''
    nearby_sources = []
    
    for source in source_list:
        distance_squared = (source['RA']-ra)**2 + (source['DEC']-dec)**2 
        if distance_squared <= radius**2: nearby_sources.append(source)# if w/i error radiues
            
    return nearby_sources

def arcmin_to_deg(arcmin):
    return arcmin/60

def scrape_inbox_msgs(inbox, print_alerts=False):
    '''
    Runs the scraper function on the results of the inbox function
    Returns a list of alert dictionaries
    '''
    alerts = []
    for mail in inbox:
        alert = general_scraper(mail['Message'], print_alert=print_alerts)
        alerts.append(alert)
    return alerts

def add_nearby_sources_to_alerts(alerts, source_list):
    '''
    Runs the find nearby sources function 
    '''
    for event in alerts:
        if 'Error 90%' in event.keys():
            event['Sources in 90% Region'] = find_nearby_sources(catalog,event['RA_J2000'],event['DEC_J2000'],event['Error 90%'])

        if 'Error 50%' in event.keys():
            event['Sources in 50% Region'] = find_nearby_sources(catalog,event['RA_J2000'],event['DEC_J2000'],event['Error 50%'])
            
    return alerts

def print_alerts(alerts):
    for event in alerts:
        for key in event.keys():
            print(key+':\t',event[key])
        print('='*100)

# %%
inbox = get_gmail('******@gmail.com', '******', subject_filter="GCN Archives")

# %%
catalog = get_catalog('gll_psc_v26.xml')
# could try using the make4FGL.py script and the fits file which may be more recent than the xml file
# https://fermi.gsfc.nasa.gov/ssc/data/access/lat/10yr_catalog/

# %%
alerts = scrape_inbox_msgs(inbox)

# %% [markdown]
# # Database

# %%
db_user = ******
db_pwd = ******
db_host = ******
db_port = ******
db_name = 'fermi'

# %%
def db_connect(username, password, host, port, database, print_confirmation=False):
    '''
    Connect to a database
    '''
    try:
        conn = mariadb.connect(user=username, password=password, host=host, port=port, database=database)
        if print_confirmation: print("Connected to",database)
    except mariadb.Error as e:
        print(f"Error conntecting to MariaDB Platform: {e}")
        sys.exit(1)

    cur = conn.cursor()
    
    return cur, conn

def clear_table(cursor,table):
    cursor.execute("DROP TABLE IF EXISTS "+table)
    
def create_alerts_table(cursor):
    string = '''CREATE TABLE IF NOT EXISTS alerts (
    db_ID INT PRIMARY KEY AUTO_INCREMENT,
    Notice_Date DATETIME,
    run INT, event INT,
    type VARCHAR(100),
    RA_J2000 FLOAT, RA_current FLOAT, RA_1950 FLOAT,
    DEC_J2000 FLOAT, DEC_current FLOAT, DEC_1950 FLOAT,
    Event_Date DATE, Event_Time TIME,
    Error_90 FLOAT, Error_50 FLOAT,
    Energy FLOAT, 
    Time FLOAT, False_Alarm_Rate FLOAT, Signalness FLOAT, Analysis INT DEFAULT 0)'''
    
    cursor.execute(string)
    
def describe_alerts_table(cursor):
    cur.execute("DESCRIBE alerts")

    print("Field \t\t Type \t\t Null \t Key \t Default \t Extra")
    for i in cur:
        print(i[0],' '*(15-len(i[0])),i[1],' '*(14-len(i[1])),i[2],'\t',i[3],'\t',i[4],'\t\t',i[5])
        
def add_alerts(cursor, alerts, print_confirmation=False):
    for alert in alerts:
        # check if duplicate
        run_event_filter = 'WHERE run='+str(alert['Run'])+' AND event='+str(alert['Event'] + ' AND type="'+alert['Type']+'"')
        matches = get_from_table(cursor,filter_string=run_event_filter) # list w/ 0 or 1 element(s)
        
        if len(matches)>0: # if duplicate, check if newer
            if matches[0]['Notice_Date']<alert['Notice Date']: # if newer, overwrite
                overwrite_string = '''UPDATE alerts 
                    SET Notice_Date='''+str(alert['Notice Date'])+'''
                        RA_J2000='''+str(alert['RA_J2000'])+'''
                        RA_current='''+str(alert['RA_current'])+'''
                        RA_1950='''+str(alert['RA_1950'])+'''
                        DEC_J2000='''+str(alert['DEC_J2000'])+'''
                        DEC_current='''+str(alert['DEC_current'])+'''
                        DEC_1950='''+str(alert['DEC_1950'])+'''
                        Event_Date='''+str(alert['Event Date'])+'''
                        Event_Time='''+str(alert['Event Time'])+'''
                        Error_90='''+str(alert['Error 90%'])+'''
                        Error_50='''+str(alert['Error 50%'])+'''
                        Energy='''+str(alert['Energy'])+'''
                        Time='''+str(alert['Time'])+'''
                        False_Alarm_Rate='''+str(alert['False Alarm Rate'])+'''
                        Signalness='''+str(alert['Signalness'])+'''
                    WHERE db_ID='''+str(matches[0]['db_ID'])
                try:
                    cursor.execute(overwrite_string)
                    if print_confirmation: print(matches[0]['db_ID'], "Overwritten successfully")
                except mariadb.Error as e:
                    print(f"Error: {e}")
         
        else: # not a duplicate, add a new entry
            alert_insert_values = tuple([str(alert[key]) for key in alert.keys()])
            insert_string = '''INSERT INTO alerts (Notice_Date,run,event,type,
                RA_J2000,RA_current,RA_1950,
                DEC_J2000,DEC_current,DEC_1950,
                Event_Date,Event_Time,
                Error_90,Error_50,
                Energy, Time, False_Alarm_Rate, Signalness) 
                VALUES '''+str(alert_insert_values)
            
            try: 
                cursor.execute(insert_string)
                if print_confirmation: print(alert_insert_values[1], alert_insert_values[2],"Written successfully")
            except mariadb.Error as e:
                print('For alert with run',alert_insert_values[1],'and event',alert_insert_values[2])
                print('For alert with run',alert_insert_values[1],'and event',alert_insert_values[2],f"Error: {e}")
                
def get_from_table(cursor,filter_string="",print_results=False):
    cursor.execute("SELECT * FROM alerts "+filter_string) # get database entries
    
    keys = ['db_ID','Notice_Date','run','event','type',
            'RA_J2000','RA_current','RA_1950','DEC_J2000','DEC_current','DEC_1950',
            'Event_Date','Event_Time','Error_90','Error_50','Energy', 'Time', 'False_Alarm_Rate', 'Signalness', 'Analysis']
    results = []
    
    for alert in cursor: # for every entry
        dict_alert = {keys[i]:alert[i] for i in range(len(keys))} # turn it into a dictionary
        results.append(dict_alert)
        if print_results:
            for key in keys:
                print(key,':\t',dict_alert[key])
            print('='*100,'\n')
    
    return results

def exit_db(connection):
    connection.commit()
    connection.close()

# %%
cur, con = db_connect(db_user,db_pwd,db_host,db_port,db_name)
# clear_table(cur,'alerts') # now we have duplicate checks don't need to delete table every time
# create_alerts_table(cur)
# describe_alerts_table(cur)
# add_alerts(cur,alerts)
all_alerts = get_from_table(cur,print_results=True)
exit_db(con)
# Out:
# db_ID :	 1
# Notice_Date :	 2021-01-11 13:15:54
# run :	 0
# event :	 73310
# type :	 AMON Neutrino-EM Coincidence
# RA_J2000 :	 162.34
# RA_current :	 162.622
# RA_1950 :	 161.669
# DEC_J2000 :	 19.46
# DEC_current :	 19.3484
# DEC_1950 :	 19.7248
# Event_Date :	 2021-01-11
# Event_Time :	 13:06:41
# Error_90 :	 0.669833
# Error_50 :	 0.369833
# Energy :	 0.0
# Time :	 22742.2
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 2
# Notice_Date :	 2021-05-15 00:43:32
# run :	 0
# event :	 85790
# type :	 AMON Neutrino-EM Coincidence
# RA_J2000 :	 93.64
# RA_current :	 93.9448
# RA_1950 :	 92.9267
# DEC_J2000 :	 14.66
# DEC_current :	 14.6521
# DEC_1950 :	 14.6759
# Event_Date :	 2021-05-15
# Event_Time :	 0:20:43
# Error_90 :	 0.267667
# Error_50 :	 0.149833
# Energy :	 0.0
# Time :	 22442.9
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 3
# Notice_Date :	 2020-11-07 16:02:47
# run :	 0
# event :	 66291
# type :	 AMON Neutrino-EM Coincidence
# RA_J2000 :	 140.2
# RA_current :	 140.509
# RA_1950 :	 139.456
# DEC_J2000 :	 29.76
# DEC_current :	 29.6706
# DEC_1950 :	 29.9727
# Event_Date :	 2020-11-07
# Event_Time :	 15:55:32
# Error_90 :	 0.271667
# Error_50 :	 0.149833
# Energy :	 0.0
# Time :	 23105.4
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 4
# Notice_Date :	 2020-11-24 14:22:13
# run :	 0
# event :	 68186
# type :	 AMON Neutrino-EM Coincidence
# RA_J2000 :	 134.99
# RA_current :	 135.269
# RA_1950 :	 134.322
# DEC_J2000 :	 7.74
# DEC_current :	 7.6575
# DEC_1950 :	 7.9357
# Event_Date :	 2020-11-24
# Event_Time :	 14:13:38
# Error_90 :	 0.418333
# Error_50 :	 0.23
# Energy :	 0.0
# Time :	 21531.2
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 5
# Notice_Date :	 2020-07-17 21:55:50
# run :	 0
# event :	 54519
# type :	 AMON Neutrino-EM Coincidence
# RA_J2000 :	 118.5
# RA_current :	 118.76
# RA_1950 :	 117.866
# DEC_J2000 :	 -1.62
# DEC_current :	 -1.6748
# DEC_1950 :	 -1.4885
# Event_Date :	 2020-07-17
# Event_Time :	 21:22:26
# Error_90 :	 0.379333
# Error_50 :	 0.209833
# Energy :	 0.0
# Time :	 19395.5
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 6
# Notice_Date :	 2021-05-15 00:43:41
# run :	 0
# event :	 85791
# type :	 AMON Neutrino-EM Coincidence
# RA_J2000 :	 93.93
# RA_current :	 94.2301
# RA_1950 :	 93.2278
# DEC_J2000 :	 12.5099
# DEC_current :	 12.5014
# DEC_1950 :	 12.5273
# Event_Date :	 2021-05-15
# Event_Time :	 0:19:27
# Error_90 :	 0.357333
# Error_50 :	 0.2
# Energy :	 0.0
# Time :	 22165.2
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 7
# Notice_Date :	 2020-06-14 15:39:18
# run :	 134187
# event :	 72386329
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 33.84
# RA_current :	 34.1413
# RA_1950 :	 33.1054
# DEC_J2000 :	 31.6099
# DEC_current :	 31.7043
# DEC_1950 :	 31.3777
# Event_Date :	 2020-06-14
# Event_Time :	 12:41:21
# Error_90 :	 4.04
# Error_50 :	 2.35
# Energy :	 1150500000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.41553
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 8
# Notice_Date :	 2020-12-09 13:59:58
# run :	 134777
# event :	 8912764
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 6.86
# RA_current :	 7.126
# RA_1950 :	 6.2247
# DEC_J2000 :	 -9.25
# DEC_current :	 -9.1343
# DEC_1950 :	 -9.5266
# Event_Date :	 2020-12-09
# Event_Time :	 10:15:43
# Error_90 :	 1.09
# Error_50 :	 0.64
# Energy :	 4186000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.19226
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 9
# Notice_Date :	 2020-01-10 01:28:19
# run :	 133609
# event :	 37927131
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 164.49
# RA_current :	 164.753
# RA_1950 :	 163.833
# DEC_J2000 :	 11.8699
# DEC_current :	 11.7624
# DEC_1950 :	 12.1377
# Event_Date :	 2020-01-09
# Event_Time :	 23:41:39
# Error_90 :	 2.91
# Error_50 :	 1.61
# Energy :	 3752300000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.76931
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 10
# Notice_Date :	 2020-10-08 01:10:57
# run :	 134577
# event :	 31638233
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 265.17
# RA_current :	 265.425
# RA_1950 :	 264.556
# DEC_J2000 :	 5.3399
# DEC_current :	 5.3304
# DEC_1950 :	 5.3648
# Event_Date :	 2020-10-07
# Event_Time :	 22:01:49
# Error_90 :	 0.4
# Error_50 :	 0.23
# Energy :	 6826500000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.88552
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 11
# Notice_Date :	 2020-06-15 16:10:37
# run :	 134191
# event :	 17593623
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 142.95
# RA_current :	 143.216
# RA_1950 :	 142.298
# DEC_J2000 :	 3.66
# DEC_current :	 3.569
# DEC_1950 :	 3.8812
# Event_Date :	 2020-06-15
# Event_Time :	 14:49:17
# Error_90 :	 1.21983
# Error_50 :	 0.719833
# Energy :	 4963600000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.82832
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 12
# Notice_Date :	 2020-07-28 08:18:48
# run :	 134327
# event :	 10548129
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 117.555
# RA_current :	 117.772
# RA_1950 :	 117.029
# DEC_J2000 :	 -24.8475
# DEC_current :	 -24.9007
# DEC_1950 :	 -24.7198
# Event_Date :	 2020-07-28
# Event_Time :	 8:17:51
# Error_90 :	 0.513333
# Error_50 :	 0.2
# Energy :	 4.2024e+17
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.3931
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 13
# Notice_Date :	 2019-08-01 15:09:25
# run :	 132910
# event :	 57145925
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 225.79
# RA_current :	 226.026
# RA_1950 :	 225.186
# DEC_J2000 :	 10.47
# DEC_current :	 10.3942
# DEC_1950 :	 10.6652
# Event_Date :	 2019-07-30
# Event_Time :	 20:50:41
# Error_90 :	 1.185
# Error_50 :	 0.662333
# Energy :	 2988100000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.67158
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 14
# Notice_Date :	 2020-04-26 03:28:30
# run :	 134013
# event :	 16038252
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 100.1
# RA_current :	 100.511
# RA_1950 :	 99.0871
# DEC_J2000 :	 53.57
# DEC_current :	 53.5498
# DEC_1950 :	 53.6164
# Event_Date :	 2020-04-25
# Event_Time :	 23:26:46
# Error_90 :	 2.97
# Error_50 :	 1.51
# Energy :	 1348700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.48106
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 15
# Notice_Date :	 2021-05-16 16:37:17
# run :	 135292
# event :	 56063172
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 91.76
# RA_current :	 92.0538
# RA_1950 :	 91.0728
# DEC_J2000 :	 9.5199
# DEC_current :	 9.5159
# DEC_1950 :	 9.5268
# Event_Date :	 2021-05-16
# Event_Time :	 14:38:20
# Error_90 :	 0.78
# Error_50 :	 0.429833
# Energy :	 1091200000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.2886
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 16
# Notice_Date :	 2020-01-01 22:07:17
# run :	 133572
# event :	 82361476
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 46.3599
# RA_current :	 46.6463
# RA_1950 :	 45.6452
# DEC_J2000 :	 20.42
# DEC_current :	 20.4966
# DEC_1950 :	 20.2266
# Event_Date :	 2020-01-01
# Event_Time :	 11:00:06
# Error_90 :	 1.71983
# Error_50 :	 1.26
# Energy :	 1553800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.46281
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 17
# Notice_Date :	 2020-09-29 21:23:48
# run :	 134552
# event :	 68615710
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 29.5199
# RA_current :	 29.7892
# RA_1950 :	 28.8714
# DEC_J2000 :	 3.47
# DEC_current :	 3.5704
# DEC_1950 :	 3.227
# Event_Date :	 2020-09-29
# Event_Time :	 17:48:36
# Error_90 :	 0.53
# Error_50 :	 0.4
# Energy :	 1828900000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.47479
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 18
# Notice_Date :	 2021-05-19 20:40:47
# run :	 135302
# event :	 36915486
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 167.69
# RA_current :	 167.952
# RA_1950 :	 167.079
# DEC_J2000 :	 -25.8725
# DEC_current :	 -25.9889
# DEC_1950 :	 -25.6008
# Event_Date :	 2021-05-19
# Event_Time :	 20:40:02
# Error_90 :	 2.151
# Error_50 :	 0.603
# Energy :	 3200400000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.33167
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 19
# Notice_Date :	 2019-09-23 01:56:41
# run :	 133091
# event :	 81419
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 167.43
# RA_current :	 167.673
# RA_1950 :	 166.815
# DEC_J2000 :	 -22.39
# DEC_current :	 -22.4972
# DEC_1950 :	 -22.1186
# Event_Date :	 2019-09-22
# Event_Time :	 9:42:45
# Error_90 :	 2.95
# Error_50 :	 1.68983
# Energy :	 3.1139e+16
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.20165
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 20
# Notice_Date :	 2021-07-31 00:17:31
# run :	 135553
# event :	 7213992
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 105.73
# RA_current :	 106.037
# RA_1950 :	 105.018
# DEC_J2000 :	 14.7899
# DEC_current :	 14.757
# DEC_1950 :	 14.8637
# Event_Date :	 2021-07-30
# Event_Time :	 22:12:40
# Error_90 :	 1.40983
# Error_50 :	 0.729833
# Energy :	 1094200000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.3193
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 21
# Notice_Date :	 2020-04-11 16:11:16
# run :	 133945
# event :	 24635982
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 242.58
# RA_current :	 242.819
# RA_1950 :	 241.99
# DEC_J2000 :	 11.6099
# DEC_current :	 11.5581
# DEC_1950 :	 11.7394
# Event_Date :	 2020-04-10
# Event_Time :	 23:19:55
# Error_90 :	 10.3698
# Error_50 :	 6.50983
# Energy :	 1100000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.30535
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 22
# Notice_Date :	 2019-07-12 03:11:47
# run :	 132814
# event :	 44222682
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 76.4599
# RA_current :	 76.7346
# RA_1950 :	 75.7569
# DEC_J2000 :	 13.06
# DEC_current :	 13.0852
# DEC_1950 :	 12.9932
# Event_Date :	 2019-07-12
# Event_Time :	 1:15:17
# Error_90 :	 4.95983
# Error_50 :	 3.04
# Energy :	 1086700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.30332
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 23
# Notice_Date :	 2019-07-04 20:54:57
# run :	 132792
# event :	 60166398
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 161.85
# RA_current :	 162.117
# RA_1950 :	 161.164
# DEC_J2000 :	 27.1099
# DEC_current :	 27.0066
# DEC_1950 :	 27.3739
# Event_Date :	 2019-07-04
# Event_Time :	 18:48:52
# Error_90 :	 2.52983
# Error_50 :	 1.51
# Energy :	 1549900000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.48607
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 24
# Notice_Date :	 2019-06-29 22:46:22
# run :	 132768
# event :	 5390846
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 27.2199
# RA_current :	 27.9803
# RA_1950 :	 25.3657
# DEC_J2000 :	 84.3299
# DEC_current :	 84.4261
# DEC_1950 :	 84.0802
# Event_Date :	 2019-06-29
# Event_Time :	 19:24:15
# Error_90 :	 4.04
# Error_50 :	 3.10983
# Energy :	 1076700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.33892
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 25
# Notice_Date :	 2020-11-20 14:12:28
# run :	 134715
# event :	 65785778
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 307.53
# RA_current :	 307.718
# RA_1950 :	 307.08
# DEC_J2000 :	 40.77
# DEC_current :	 40.841
# DEC_1950 :	 40.6013
# Event_Date :	 2020-11-20
# Event_Time :	 9:44:40
# Error_90 :	 4.67983
# Error_50 :	 2.64
# Energy :	 1539600000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.50338
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 26
# Notice_Date :	 2020-08-06 15:43:37
# run :	 134354
# event :	 59221243
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 157.25
# RA_current :	 157.562
# RA_1950 :	 156.488
# DEC_J2000 :	 47.75
# DEC_current :	 47.6441
# DEC_1950 :	 48.006
# Event_Date :	 2020-08-06
# Event_Time :	 13:50:56
# Error_90 :	 0.849833
# Error_50 :	 0.479833
# Energy :	 1073500000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.39728
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 27
# Notice_Date :	 2020-01-20 23:56:49
# run :	 133644
# event :	 43767651
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 67.4599
# RA_current :	 67.6899
# RA_1950 :	 66.8866
# DEC_J2000 :	 -14.63
# DEC_current :	 -14.5874
# DEC_1950 :	 -14.738
# Event_Date :	 2020-01-20
# Event_Time :	 18:48:18
# Error_90 :	 0.34
# Error_50 :	 0.22
# Energy :	 6.0702e+16
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.32893
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 28
# Notice_Date :	 2020-09-21 20:41:52
# run :	 134512
# event :	 71996695
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 195.29
# RA_current :	 195.54
# RA_1950 :	 194.685
# DEC_J2000 :	 26.2399
# DEC_current :	 26.1287
# DEC_1950 :	 26.5088
# Event_Date :	 2020-09-21
# Event_Time :	 19:07:12
# Error_90 :	 2.83983
# Error_50 :	 1.07
# Energy :	 1171700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.40945
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 29
# Notice_Date :	 2020-10-21 12:31:38
# run :	 134621
# event :	 31008065
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 260.92
# RA_current :	 261.157
# RA_1950 :	 260.351
# DEC_J2000 :	 14.55
# DEC_current :	 14.532
# DEC_1950 :	 14.5953
# Event_Date :	 2020-10-21
# Event_Time :	 6:37:47
# Error_90 :	 1.37983
# Error_50 :	 0.819833
# Energy :	 1052700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.29662
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 30
# Notice_Date :	 2019-12-15 14:46:24
# run :	 133433
# event :	 29047901
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 285.87
# RA_current :	 285.948
# RA_1950 :	 285.673
# DEC_J2000 :	 58.92
# DEC_current :	 58.9505
# DEC_1950 :	 58.8443
# Event_Date :	 2019-12-15
# Event_Time :	 11:09:57
# Error_90 :	 2.54
# Error_50 :	 1.25
# Energy :	 1326500000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.4749
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 31
# Notice_Date :	 2021-06-08 11:54:47
# run :	 135363
# event :	 69917294
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 337.41
# RA_current :	 337.669
# RA_1950 :	 336.805
# DEC_J2000 :	 18.37
# DEC_current :	 18.4803
# DEC_1950 :	 18.1135
# Event_Date :	 2021-06-08
# Event_Time :	 3:41:00
# Error_90 :	 5.87983
# Error_50 :	 2.68983
# Energy :	 1051700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.3147
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 32
# Notice_Date :	 2020-09-26 23:56:27
# run :	 134535
# event :	 41069485
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 184.75
# RA_current :	 185.009
# RA_1950 :	 184.124
# DEC_J2000 :	 32.9299
# DEC_current :	 32.8149
# DEC_1950 :	 33.2075
# Event_Date :	 2020-09-26
# Event_Time :	 22:35:29
# Error_90 :	 1.81
# Error_50 :	 1.11
# Energy :	 1214200000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.43381
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 33
# Notice_Date :	 2021-08-11 04:04:21
# run :	 135591
# event :	 36044887
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 270.79
# RA_current :	 271.01
# RA_1950 :	 270.281
# DEC_J2000 :	 25.28
# DEC_current :	 25.2819
# DEC_1950 :	 25.2774
# Event_Date :	 2021-08-11
# Event_Time :	 2:02:44
# Error_90 :	 0.936
# Error_50 :	 0.537
# Energy :	 2176700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.65826
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 34
# Notice_Date :	 2020-05-23 04:06:09
# run :	 134116
# event :	 58596690
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 338.64
# RA_current :	 338.9
# RA_1950 :	 338.002
# DEC_J2000 :	 1.75
# DEC_current :	 1.8558
# DEC_1950 :	 1.4913
# Event_Date :	 2020-05-23
# Event_Time :	 2:30:07
# Error_90 :	 5.55983
# Error_50 :	 3.64
# Energy :	 1050800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.24998
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 35
# Notice_Date :	 2020-11-15 16:02:27
# run :	 134701
# event :	 49508272
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 148.752
# RA_current :	 148.995
# RA_1950 :	 148.169
# DEC_J2000 :	 -21.6418
# DEC_current :	 -21.7413
# DEC_1950 :	 -21.4045
# Event_Date :	 2020-11-15
# Event_Time :	 16:01:42
# Error_90 :	 0.864833
# Error_50 :	 0.336833
# Energy :	 2.6182e+17
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.49261
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 36
# Notice_Date :	 2020-02-27 05:37:09
# run :	 133781
# event :	 21701751
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 348.26
# RA_current :	 348.509
# RA_1950 :	 347.642
# DEC_J2000 :	 21.3235
# DEC_current :	 21.4334
# DEC_1950 :	 21.0512
# Event_Date :	 2020-02-27
# Event_Time :	 5:36:31
# Error_90 :	 0.513333
# Error_50 :	 0.2
# Energy :	 1095000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.35075
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 37
# Notice_Date :	 2019-11-23 00:33:42
# run :	 133348
# event :	 80807014
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 27.25
# RA_current :	 27.5049
# RA_1950 :	 26.6098
# DEC_J2000 :	 -0.04
# DEC_current :	 0.0583
# DEC_1950 :	 -0.2882
# Event_Date :	 2019-11-22
# Event_Time :	 22:45:10
# Error_90 :	 1.82
# Error_50 :	 1.09
# Energy :	 1284400000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.33128
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 38
# Notice_Date :	 2019-10-02 18:43:07
# run :	 133119
# event :	 22683750
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 314.08
# RA_current :	 314.315
# RA_1950 :	 313.485
# DEC_J2000 :	 12.9399
# DEC_current :	 13.0165
# DEC_1950 :	 12.7473
# Event_Date :	 2019-10-01
# Event_Time :	 20:09:18
# Error_90 :	 2.95
# Error_50 :	 1.35
# Energy :	 2174200000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.58898
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 39
# Notice_Date :	 2019-06-19 15:46:29
# run :	 132707
# event :	 54984442
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 343.26
# RA_current :	 343.503
# RA_1950 :	 342.635
# DEC_J2000 :	 10.73
# DEC_current :	 10.8338
# DEC_1950 :	 10.4638
# Event_Date :	 2019-06-19
# Event_Time :	 13:14:18
# Error_90 :	 2.70983
# Error_50 :	 1.62983
# Energy :	 1987000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.54551
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 40
# Notice_Date :	 2021-02-13 18:40:59
# run :	 134994
# event :	 1103075
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 155.258
# RA_current :	 155.494
# RA_1950 :	 154.701
# DEC_J2000 :	 -35.3994
# DEC_current :	 -35.5063
# DEC_1950 :	 -35.1471
# Event_Date :	 2021-02-13
# Event_Time :	 18:40:24
# Error_90 :	 1.19
# Error_50 :	 0.382333
# Energy :	 1.4504e+16
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.6073
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 41
# Notice_Date :	 2020-11-14 20:00:28
# run :	 134698
# event :	 40735501
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 105.25
# RA_current :	 105.529
# RA_1950 :	 104.581
# DEC_J2000 :	 6.0499
# DEC_current :	 6.0191
# DEC_1950 :	 6.1216
# Event_Date :	 2020-11-14
# Event_Time :	 15:05:31
# Error_90 :	 1.08
# Error_50 :	 0.569833
# Energy :	 2142900000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.56208
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 42
# Notice_Date :	 2020-01-17 14:25:18
# run :	 133634
# event :	 1410505
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 116.24
# RA_current :	 116.552
# RA_1950 :	 115.459
# DEC_J2000 :	 29.1299
# DEC_current :	 29.0803
# DEC_1950 :	 29.2513
# Event_Date :	 2020-01-17
# Event_Time :	 11:08:29
# Error_90 :	 0.91
# Error_50 :	 0.51
# Energy :	 1083900000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.3754
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 43
# Notice_Date :	 2020-11-15 14:14:08
# run :	 134699
# event :	 70289682
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 195.12
# RA_current :	 195.387
# RA_1950 :	 194.481
# DEC_J2000 :	 1.3799
# DEC_current :	 1.2678
# DEC_1950 :	 1.6491
# Event_Date :	 2020-11-15
# Event_Time :	 2:07:26
# Error_90 :	 1.29
# Error_50 :	 0.709833
# Energy :	 1773800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.45973
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 44
# Notice_Date :	 2019-08-19 17:34:54
# run :	 132974
# event :	 67924813
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 148.807
# RA_current :	 149.059
# RA_1950 :	 148.164
# DEC_J2000 :	 0.9571
# DEC_current :	 0.8635
# DEC_1950 :	 1.1944
# Event_Date :	 2019-08-19
# Event_Time :	 17:34:24
# Error_90 :	 0.513333
# Error_50 :	 0.2
# Energy :	 1131600000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.29215
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 45
# Notice_Date :	 2019-12-05 03:45:54
# run :	 133394
# event :	 27261780
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 79.7199
# RA_current :	 79.9806
# RA_1950 :	 79.0661
# DEC_J2000 :	 2.7999
# DEC_current :	 2.8194
# DEC_1950 :	 2.7487
# Event_Date :	 2019-12-04
# Event_Time :	 22:46:11
# Error_90 :	 1.82
# Error_50 :	 0.989833
# Energy :	 1302000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.32711
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 46
# Notice_Date :	 2021-05-10 04:50:47
# run :	 135270
# event :	 69188496
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 267.911
# RA_current :	 268.176
# RA_1950 :	 267.29
# DEC_J2000 :	 4.0004
# DEC_current :	 3.9963
# DEC_1950 :	 4.0121
# Event_Date :	 2021-05-10
# Event_Time :	 4:50:10
# Error_90 :	 0.513333
# Error_50 :	 0.2
# Energy :	 1130300000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.28151
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 47
# Notice_Date :	 2020-12-22 02:34:38
# run :	 134818
# event :	 73718836
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 206.37
# RA_current :	 206.626
# RA_1950 :	 205.759
# DEC_J2000 :	 13.4399
# DEC_current :	 13.3354
# DEC_1950 :	 13.69
# Event_Date :	 2020-12-22
# Event_Time :	 0:56:16
# Error_90 :	 0.66
# Error_50 :	 0.369833
# Energy :	 1857800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.5337
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 48
# Notice_Date :	 2020-09-26 14:30:27
# run :	 134533
# event :	 53384881
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 96.4599
# RA_current :	 96.7169
# RA_1950 :	 95.8403
# DEC_J2000 :	 -4.33
# DEC_current :	 -4.3432
# DEC_1950 :	 -4.3002
# Event_Date :	 2020-09-26
# Event_Time :	 7:54:11
# Error_90 :	 0.66
# Error_50 :	 0.39
# Energy :	 6705000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.44137
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 49
# Notice_Date :	 2021-06-29 20:36:00
# run :	 135440
# event :	 3139778
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 340.75
# RA_current :	 341.016
# RA_1950 :	 340.131
# DEC_J2000 :	 12.9399
# DEC_current :	 13.053
# DEC_1950 :	 12.6776
# Event_Date :	 2021-06-29
# Event_Time :	 18:09:44
# Error_90 :	 1.3
# Error_50 :	 0.77
# Energy :	 1209500000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.35083
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 50
# Notice_Date :	 2020-04-21 03:10:28
# run :	 133985
# event :	 60770138
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 87.93
# RA_current :	 88.2065
# RA_1950 :	 87.2493
# DEC_J2000 :	 8.23
# DEC_current :	 8.2338
# DEC_1950 :	 8.2183
# Event_Date :	 2020-04-21
# Event_Time :	 0:35:24
# Error_90 :	 2.54983
# Error_50 :	 1.48983
# Energy :	 1269700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.33312
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 51
# Notice_Date :	 2021-03-22 02:34:57
# run :	 135113
# event :	 19489408
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 85.5066
# RA_current :	 85.6619
# RA_1950 :	 85.141
# DEC_J2000 :	 -44.7217
# DEC_current :	 -44.7126
# DEC_1950 :	 -44.7444
# Event_Date :	 2021-03-22
# Event_Time :	 2:34:09
# Error_90 :	 0.652167
# Error_50 :	 0.234833
# Energy :	 548530000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.45899
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 52
# Notice_Date :	 2020-11-30 22:56:38
# run :	 134751
# event :	 31476488
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 30.5399
# RA_current :	 30.7952
# RA_1950 :	 29.9297
# DEC_J2000 :	 -12.0999
# DEC_current :	 -11.9997
# DEC_1950 :	 -12.3404
# Event_Date :	 2020-11-30
# Event_Time :	 20:21:46
# Error_90 :	 1.17983
# Error_50 :	 0.689833
# Energy :	 2034700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.14696
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 53
# Notice_Date :	 2020-09-11 17:39:39
# run :	 134482
# event :	 27754576
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 51.1099
# RA_current :	 51.4457
# RA_1950 :	 50.3009
# DEC_J2000 :	 38.1099
# DEC_current :	 38.182
# DEC_1950 :	 37.9336
# Event_Date :	 2020-09-11
# Event_Time :	 14:19:46
# Error_90 :	 4.94
# Error_50 :	 1.56
# Energy :	 1107900000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.40813
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 54
# Notice_Date :	 2020-09-16 22:20:58
# run :	 134498
# event :	 12605830
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 109.78
# RA_current :	 110.073
# RA_1950 :	 109.072
# DEC_J2000 :	 14.3599
# DEC_current :	 14.3206
# DEC_1950 :	 14.4525
# Event_Date :	 2020-09-16
# Event_Time :	 20:40:30
# Error_90 :	 1.06
# Error_50 :	 0.579833
# Energy :	 1104800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.32226
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 55
# Notice_Date :	 2020-12-21 14:32:41
# run :	 134817
# event :	 29175858
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 261.69
# RA_current :	 261.855
# RA_1950 :	 261.296
# DEC_J2000 :	 41.81
# DEC_current :	 41.7933
# DEC_1950 :	 41.8512
# Event_Date :	 2020-12-21
# Event_Time :	 12:36:53
# Error_90 :	 1.82
# Error_50 :	 1.02
# Energy :	 1745400000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.56429
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 56
# Notice_Date :	 2020-05-12 15:18:48
# run :	 134081
# event :	 58268464
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 295.18
# RA_current :	 295.412
# RA_1950 :	 294.611
# DEC_J2000 :	 15.7899
# DEC_current :	 15.8383
# DEC_1950 :	 15.6727
# Event_Date :	 2020-05-12
# Event_Time :	 7:31:27
# Error_90 :	 1.62983
# Error_50 :	 0.9
# Energy :	 1087700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.32159
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 57
# Notice_Date :	 2020-10-14 04:43:29
# run :	 134599
# event :	 66310113
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 221.22
# RA_current :	 221.467
# RA_1950 :	 220.627
# DEC_J2000 :	 14.4399
# DEC_current :	 14.353
# DEC_1950 :	 14.6503
# Event_Date :	 2020-10-14
# Event_Time :	 2:13:27
# Error_90 :	 0.839833
# Error_50 :	 0.52
# Energy :	 1469300000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.41371
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 58
# Notice_Date :	 2019-11-19 02:59:55
# run :	 133331
# event :	 47828126
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 230.1
# RA_current :	 230.352
# RA_1950 :	 229.468
# DEC_J2000 :	 2.1699
# DEC_current :	 2.0991
# DEC_1950 :	 2.3497
# Event_Date :	 2019-11-19
# Event_Time :	 1:01:29
# Error_90 :	 3.66983
# Error_50 :	 2.56983
# Energy :	 1764800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.44999
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 59
# Notice_Date :	 2020-06-20 13:35:05
# run :	 134207
# event :	 33533447
# type :	 ICECUBE Astrotrack Bronze
# RA_J2000 :	 162.11
# RA_current :	 162.38
# RA_1950 :	 161.451
# DEC_J2000 :	 11.9499
# DEC_current :	 11.8414
# DEC_1950 :	 12.2143
# Event_Date :	 2020-06-20
# Event_Time :	 3:03:32
# Error_90 :	 0.68
# Error_50 :	 0.349833
# Energy :	 1135000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.32464
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 60
# Notice_Date :	 2020-05-30 14:41:57
# run :	 134139
# event :	 35473338
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 255.37
# RA_current :	 255.576
# RA_1950 :	 254.865
# DEC_J2000 :	 26.6099
# DEC_current :	 26.5814
# DEC_1950 :	 26.6814
# Event_Date :	 2020-05-30
# Event_Time :	 7:54:29
# Error_90 :	 2.66983
# Error_50 :	 1.09
# Energy :	 821860000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.5917
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 61
# Notice_Date :	 2019-09-23 02:46:50
# run :	 133092
# event :	 52499868
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 5.7599
# RA_current :	 6.0123
# RA_1950 :	 5.1202
# DEC_J2000 :	 -1.57
# DEC_current :	 -1.4608
# DEC_1950 :	 -1.8472
# Event_Date :	 2019-09-22
# Event_Time :	 23:03:55
# Error_90 :	 1.08
# Error_50 :	 0.609833
# Energy :	 1873700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.50501
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 62
# Notice_Date :	 2021-02-10 14:43:07
# run :	 134979
# event :	 17138286
# type :	 ICECUBE Astrotrack Gold
# RA_J2000 :	 206.06
# RA_current :	 206.326
# RA_1950 :	 205.43
# DEC_J2000 :	 4.78
# DEC_current :	 4.6745
# DEC_1950 :	 5.0308
# Event_Date :	 2021-02-10
# Event_Time :	 11:53:55
# Error_90 :	 0.88
# Error_50 :	 0.53
# Energy :	 2874100000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.65464
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 63
# Notice_Date :	 2019-05-03 17:23:39
# run :	 132508
# event :	 42419327
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 120.304
# RA_current :	 120.562
# RA_1950 :	 119.636
# DEC_J2000 :	 6.3568
# DEC_current :	 6.3023
# DEC_1950 :	 6.4959
# Event_Date :	 2019-05-03
# Event_Time :	 17:23:08
# Error_90 :	 0.249833
# Error_50 :	 0.0
# Energy :	 1000000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 64
# Notice_Date :	 2017-03-21 07:32:58
# run :	 129307
# event :	 80305071
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 98.3268
# RA_current :	 98.5229
# RA_1950 :	 97.7574
# DEC_J2000 :	 -14.4861
# DEC_current :	 -14.5001
# DEC_1950 :	 -14.4472
# Event_Date :	 2017-03-21
# Event_Time :	 7:32:20
# Error_90 :	 0.324667
# Error_50 :	 0.0
# Energy :	 1199800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 65
# Notice_Date :	 2016-08-06 12:22:10
# run :	 128311
# event :	 26552458
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 122.798
# RA_current :	 123.01
# RA_1950 :	 122.16
# DEC_J2000 :	 -0.7331
# DEC_current :	 -0.7833
# DEC_1950 :	 -0.5836
# Event_Date :	 2016-08-06
# Event_Time :	 12:21:33
# Error_90 :	 0.111167
# Error_50 :	 0.0
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 66
# Notice_Date :	 2018-09-08 20:00:16
# run :	 131475
# event :	 34507973
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 145.773
# RA_current :	 146.01
# RA_1950 :	 145.139
# DEC_J2000 :	 -2.5178
# DEC_current :	 -2.6039
# DEC_1950 :	 -2.2885
# Event_Date :	 2018-09-08
# Event_Time :	 19:59:31
# Error_90 :	 0.339333
# Error_50 :	 0.0
# Energy :	 1199800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 67
# Notice_Date :	 2016-12-11 16:04:50
# run :	 128906
# event :	 80127519
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 46.5799
# RA_current :	 46.8154
# RA_1950 :	 45.8859
# DEC_J2000 :	 14.98
# DEC_current :	 15.0447
# DEC_1950 :	 14.7874
# Event_Date :	 2016-12-10
# Event_Time :	 20:06:40
# Error_90 :	 1.0
# Error_50 :	 0.0
# Energy :	 1000000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 68
# Notice_Date :	 2018-10-23 16:38:11
# run :	 131653
# event :	 53411354
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 269.836
# RA_current :	 270.093
# RA_1950 :	 269.152
# DEC_J2000 :	 -8.8863
# DEC_current :	 -8.8864
# DEC_1950 :	 -8.8838
# Event_Date :	 2018-10-23
# Event_Time :	 16:37:32
# Error_90 :	 0.291667
# Error_50 :	 0.0
# Energy :	 1199800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 69
# Notice_Date :	 2017-09-22 20:55:13
# run :	 130033
# event :	 50579430
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 77.2853
# RA_current :	 77.5221
# RA_1950 :	 76.6176
# DEC_J2000 :	 5.7517
# DEC_current :	 5.7732
# DEC_1950 :	 5.6888
# Event_Date :	 2017-09-22
# Event_Time :	 20:54:30
# Error_90 :	 0.249833
# Error_50 :	 0.0
# Energy :	 1199800000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 70
# Notice_Date :	 2016-07-31 01:55:45
# run :	 128290
# event :	 6888376
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 215.109
# RA_current :	 215.322
# RA_1950 :	 214.467
# DEC_J2000 :	 -0.4581
# DEC_current :	 -0.5335
# DEC_1950 :	 -0.2295
# Event_Date :	 2016-07-31
# Event_Time :	 1:55:04
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 71
# Notice_Date :	 2016-07-31 01:55:58
# run :	 128290
# event :	 6888376
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 215.093
# RA_current :	 215.306
# RA_1950 :	 214.452
# DEC_J2000 :	 -0.4191
# DEC_current :	 -0.4945
# DEC_1950 :	 -0.1904
# Event_Date :	 2016-07-31
# Event_Time :	 1:55:04
# Error_90 :	 0.171833
# Error_50 :	 0.0
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 72
# Notice_Date :	 2017-11-06 18:40:24
# run :	 130214
# event :	 17569642
# type :	 AMON ICECUBE EHE
# RA_J2000 :	 340.25
# RA_current :	 340.474
# RA_1950 :	 339.621
# DEC_J2000 :	 7.314
# DEC_current :	 7.4076
# DEC_1950 :	 7.0525
# Event_Date :	 2017-11-06
# Event_Time :	 18:39:39
# Error_90 :	 0.249833
# Error_50 :	 0.0
# Energy :	 2299900000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 73
# Notice_Date :	 2019-05-04 18:26:49
# run :	 132518
# event :	 766165
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 65.7866
# RA_current :	 65.9592
# RA_1950 :	 65.3406
# DEC_J2000 :	 -37.4431
# DEC_current :	 -37.3991
# DEC_1950 :	 -37.5583
# Event_Date :	 2019-05-04
# Event_Time :	 18:25:18
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 74
# Notice_Date :	 2018-10-14 11:52:46
# run :	 131624
# event :	 12296708
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 225.184
# RA_current :	 225.476
# RA_1950 :	 224.408
# DEC_J2000 :	 -34.792
# DEC_current :	 -34.8655
# DEC_1950 :	 -34.5944
# Event_Date :	 2018-10-14
# Event_Time :	 11:52:19
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 75
# Notice_Date :	 2016-11-03 14:07:40
# run :	 128672
# event :	 38561326
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 40.8252
# RA_current :	 41.0547
# RA_1950 :	 40.1448
# DEC_J2000 :	 12.5592
# DEC_current :	 12.63
# DEC_1950 :	 12.3475
# Event_Date :	 2016-11-03
# Event_Time :	 9:07:31
# Error_90 :	 1.1
# Error_50 :	 0.65
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 76
# Notice_Date :	 2018-04-23 02:29:12
# run :	 130949
# event :	 71165249
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 294.882
# RA_current :	 294.832
# RA_1950 :	 295.013
# DEC_J2000 :	 71.953
# DEC_current :	 71.9958
# DEC_1950 :	 71.8356
# Event_Date :	 2018-04-23
# Event_Time :	 2:28:40
# Error_90 :	 8.9
# Error_50 :	 1.6
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 77
# Notice_Date :	 2019-01-24 03:44:35
# run :	 132077
# event :	 9759013
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 307.192
# RA_current :	 307.49
# RA_1950 :	 306.41
# DEC_J2000 :	 -32.2914
# DEC_current :	 -32.227
# DEC_1950 :	 -32.4582
# Event_Date :	 2019-01-24
# Event_Time :	 3:43:54
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 78
# Notice_Date :	 2019-01-04 08:35:14
# run :	 131999
# event :	 68269692
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 359.33
# RA_current :	 359.574
# RA_1950 :	 358.687
# DEC_J2000 :	 -25.3659
# DEC_current :	 -25.2601
# DEC_1950 :	 -25.6443
# Event_Date :	 2019-01-04
# Event_Time :	 8:34:38
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 79
# Notice_Date :	 2019-02-21 08:26:07
# run :	 132229
# event :	 66688965
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 267.365
# RA_current :	 267.643
# RA_1950 :	 266.64
# DEC_J2000 :	 -16.9379
# DEC_current :	 -16.9425
# DEC_1950 :	 -16.9233
# Event_Date :	 2019-02-21
# Event_Time :	 8:25:39
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 80
# Notice_Date :	 2017-10-28 08:28:50
# run :	 130171
# event :	 34032434
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 275.076
# RA_current :	 275.236
# RA_1950 :	 274.626
# DEC_J2000 :	 34.5011
# DEC_current :	 34.51
# DEC_1950 :	 34.4776
# Event_Date :	 2017-10-28
# Event_Time :	 8:28:14
# Error_90 :	 8.9
# Error_50 :	 1.6
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 81
# Notice_Date :	 2019-02-05 21:21:44
# run :	 132143
# event :	 36142391
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 128.696
# RA_current :	 128.829
# RA_1950 :	 128.347
# DEC_J2000 :	 -53.3143
# DEC_current :	 -53.3809
# DEC_1950 :	 -53.1409
# Event_Date :	 2019-02-05
# Event_Time :	 21:21:10
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 82
# Notice_Date :	 2016-08-14 21:46:36
# run :	 128340
# event :	 58537957
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 199.31
# RA_current :	 199.542
# RA_1950 :	 198.613
# DEC_J2000 :	 -32.0165
# DEC_current :	 -32.1038
# DEC_1950 :	 -31.7532
# Event_Date :	 2016-08-14
# Event_Time :	 21:45:54
# Error_90 :	 1.48983
# Error_50 :	 0.479833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 83
# Notice_Date :	 2019-03-31 06:56:27
# run :	 132379
# event :	 15947448
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 355.635
# RA_current :	 355.858
# RA_1950 :	 355.06
# DEC_J2000 :	 71.117
# DEC_current :	 71.2238
# DEC_1950 :	 70.8395
# Event_Date :	 2019-03-31
# Event_Time :	 6:55:43
# Error_90 :	 8.9
# Error_50 :	 1.6
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 84
# Notice_Date :	 2016-04-27 14:39:05
# run :	 127853
# event :	 67093193
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 239.664
# RA_current :	 239.864
# RA_1950 :	 239.053
# DEC_J2000 :	 6.8528
# DEC_current :	 6.807
# DEC_1950 :	 6.9947
# Event_Date :	 2016-04-27
# Event_Time :	 5:52:32
# Error_90 :	 8.9
# Error_50 :	 1.6
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 85
# Notice_Date :	 2018-10-31 02:03:33
# run :	 131680
# event :	 66412090
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 182.792
# RA_current :	 183.047
# RA_1950 :	 182.122
# DEC_J2000 :	 -68.3884
# DEC_current :	 -68.4931
# DEC_1950 :	 -68.1103
# Event_Date :	 2018-10-31
# Event_Time :	 2:02:51
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 86
# Notice_Date :	 2017-03-12 13:50:29
# run :	 129281
# event :	 65274589
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 304.73
# RA_current :	 304.989
# RA_1950 :	 303.976
# DEC_J2000 :	 -26.238
# DEC_current :	 -26.1833
# DEC_1950 :	 -26.3951
# Event_Date :	 2017-03-12
# Event_Time :	 13:49:39
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 87
# Notice_Date :	 2019-05-29 01:55:49
# run :	 132628
# event :	 41485283
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 287.319
# RA_current :	 287.075
# RA_1950 :	 287.938
# DEC_J2000 :	 78.1432
# DEC_current :	 78.1751
# DEC_1950 :	 78.0589
# Event_Date :	 2019-05-29
# Event_Time :	 1:55:22
# Error_90 :	 8.9
# Error_50 :	 1.6
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 88
# Notice_Date :	 2017-05-06 13:01:20
# run :	 129474
# event :	 32674593
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 221.675
# RA_current :	 221.929
# RA_1950 :	 220.945
# DEC_J2000 :	 -26.0359
# DEC_current :	 -26.1079
# DEC_1950 :	 -25.8268
# Event_Date :	 2017-05-06
# Event_Time :	 12:36:55
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 89
# Notice_Date :	 2017-10-15 01:35:02
# run :	 130126
# event :	 56068624
# type :	 AMON ICECUBE HESE
# RA_J2000 :	 162.579
# RA_current :	 162.798
# RA_1950 :	 161.962
# DEC_J2000 :	 -15.8611
# DEC_current :	 -15.9556
# DEC_1950 :	 -15.5959
# Event_Date :	 2017-10-15
# Event_Time :	 1:34:30
# Error_90 :	 1.22983
# Error_50 :	 0.419833
# Energy :	 0.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 90
# Notice_Date :	 2021-01-21 03:00:15
# run :	 134912
# event :	 80902176
# type :	 ICECUBE Cascade
# RA_J2000 :	 211.133
# RA_current :	 211.409
# RA_1950 :	 210.478
# DEC_J2000 :	 -5.8941
# DEC_current :	 -5.9943
# DEC_1950 :	 -5.655
# Event_Date :	 2021-01-21
# Event_Time :	 2:55:00
# Error_90 :	 20.93
# Error_50 :	 11.48
# Energy :	 900700000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 91
# Notice_Date :	 2021-03-29 16:45:57
# run :	 135136
# event :	 69399950
# type :	 ICECUBE Cascade
# RA_J2000 :	 32.4624
# RA_current :	 32.7055
# RA_1950 :	 31.8901
# DEC_J2000 :	 -24.5896
# DEC_current :	 -24.49
# DEC_1950 :	 -24.8252
# Event_Date :	 2021-03-29
# Event_Time :	 16:40:29
# Error_90 :	 11.32
# Error_50 :	 6.21
# Energy :	 882300000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================
#
# db_ID :	 92
# Notice_Date :	 2021-04-16 02:03:57
# run :	 135196
# event :	 31863828
# type :	 ICECUBE Cascade
# RA_J2000 :	 194.187
# RA_current :	 194.463
# RA_1950 :	 193.539
# DEC_J2000 :	 -6.2888
# DEC_current :	 -6.4036
# DEC_1950 :	 -6.0185
# Event_Date :	 2021-04-16
# Event_Time :	 1:58:00
# Error_90 :	 19.85
# Error_50 :	 10.89
# Energy :	 302000000000000.0
# Time :	 0.0
# False_Alarm_Rate :	 0.0
# Signalness :	 0.0
# Analysis :	 0
# ====================================================================================================

# %%
alerts_with_nearby = add_nearby_sources_to_alerts(alerts,catalog)

# %% [markdown]
# # Config
# for every alert which needs analysis
# run analysis on every source in the 90% region (except cascade: 50%)

# %%
def needs_analysis(alerts):
    '''
    Figure out which alerts need to analysed
    '''
    to_be_analysed = []
    for i in alerts:
        if i['Analyis']==0:
            to_be_analysed.append(i)
    return to_be_analysed

def clean_text(text):
    # clean text for creating a folder
    string = ""
    for c in text:
        if c.isalnum() or c=='-' or c=='+': string+=c
        else: string+='_'
    return string

def make_config(alert,source):
    # should add a way to update tmax
    config = yaml.safe_load(open('defaultconfig.yaml'))
    
    # setup up outdir: type/alert/source
    type_folder = clean_text(alert['Type'].strip())
    alert_folder = clean_text(str(alert['Run'])+'_'+str(alert['Event']))
    source_folder = clean_text(source['Name'])
    # ensure directories exist
    if not os.path.isdir(type_folder): os.mkdir(type_folder)
    if not os.path.isdir(type_folder+'/'+alert_folder): os.mkdir(type_folder+'/'+alert_folder)
    if not os.path.isdir(type_folder+'/'+alert_folder+'/'+source_folder): os.mkdir(type_folder+'/'+alert_folder+'/'+source_folder)
    # set config outdir
    config['fileio'] = {'outdir' : type_folder+'/'+alert_folder+'/'+source_folder}
    
    # set fermipy target
    config['selection']['target'] = source['Name']
    
    # set fermipy start time
    fermi_start = datetime(year=2008, month=8, day=4, hour=15, minute=43, second=36)
    fermi_start_sec = 239557417
    t = time.fromisoformat(alert['Event Time']) # get event time
    event_dt = datetime.combine(alert['Event Date'],time=t) # combine event date/time
#     t = (alert['Event Time'].seconds) # get event time
#     event_dt = datetime.combine(alert['Event Date'],time=time(t//3600,(t%3600)//60,(t%3600)%60)) # combine event date/time
    pre_event_dt = event_dt - relativedelta(months=-6) # get 6mo before event
    dif = pre_event_dt - fermi_start # how long after fermi started
    config['selection']['tmin'] = fermi_start_sec + dif.seconds # convert to fermi seconds
    
    yaml.dump(config,open(type_folder+'/'+alert_folder+'/'+source_folder+'/config.yaml','w'))

# %%
print(all_alerts[18])
print('\n\n')
print(alerts_with_nearby[28])
# Out:
# {'db_ID': 19, 'Notice_Date': datetime.datetime(2019, 9, 23, 1, 56, 41), 'run': 133091, 'event': 81419, 'type': 'ICECUBE Astrotrack Gold', 'RA_J2000': 167.43, 'RA_current': 167.673, 'RA_1950': 166.815, 'DEC_J2000': -22.39, 'DEC_current': -22.4972, 'DEC_1950': -22.1186, 'Event_Date': datetime.date(2019, 9, 22), 'Event_Time': datetime.timedelta(seconds=34965), 'Error_90': 2.95, 'Error_50': 1.68983, 'Energy': 3.1139e+16, 'Time': 0.0, 'False_Alarm_Rate': 0.0, 'Signalness': 0.20165, 'Analysis': 0}
#
#
#
# {'Notice Date': datetime.datetime(2019, 9, 23, 1, 56, 41), 'Run': '133091', 'Event': '81419', 'Type': 'ICECUBE Astrotrack Gold', 'RA_J2000': 167.43, 'RA_current': 167.6729, 'RA_1950': 166.8149, 'DEC_J2000': -22.39, 'DEC_current': -22.4972, 'DEC_1950': -22.1186, 'Event Date': '19/09/22', 'Event Time': '09:42:45.62', 'Error 90%': 2.95, 'Error 50%': 1.6898333333333333, 'Energy': 3.1139e+16, 'Time': 0, 'False Alarm Rate': 0, 'Signalness': 0.20165, 'Sources in 90% Region': [{'Name': '4FGL J1100.0-2044', 'RA': 165.017, 'DEC': -20.7439, 'Flux': 1.4953090184e-06}, {'Name': '4FGL J1103.6-2329', 'RA': 165.9091, 'DEC': -23.4957, 'Flux': 3.40604223433e-06}, {'Name': '4FGL J1120.0-2204', 'RA': 170.0016, 'DEC': -22.0779, 'Flux': 1.05635464524e-05}], 'Sources in 50% Region': []}

# %%
for py_alert in alerts_with_nearby:
    if 'Cascade' not in py_alert['Type']:
        for i in py_alert['Sources in 90% Region']:
            make_config(py_alert,i)
    else:
        for i in py_alert['Sources in 50% Region']:
            make_config(py_alert,i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-21daca235d9d> in <module>
#       2     if 'Cascade' not in py_alert['Type']:
#       3         for i in py_alert['Sources in 90% Region']:
# ----> 4             make_config(py_alert,i)
#       5     else:
#       6         for i in py_alert['Sources in 50% Region']:
#
# <ipython-input-44-825aa48f7c12> in make_config(alert, source)
#      20     fermi_start = datetime(year=2008, month=8, day=4, hour=15, minute=43, second=36)
#      21     fermi_start_sec = 239557417
# ---> 22     t = time.fromisoformat(alert['Event Time']) # get event time
#      23     event_dt = datetime.combine(alert['Event Date'],time=t) # combine event date/time
#      24 #     t = (alert['Event Time'].seconds) # get event time
#
# ValueError: Invalid isoformat string: '12:41:21.41'
